# %%
import numpy             as np
import matplotlib.pyplot as plt
import matplotlib.cm as cm
import wsgg              as w
# %matplotlib inline

# %%
P = 101325
XH2O = 0.80
XCO2 = 1.0-XH2O
print(XH2O/XCO2)

n = 1000
T = np.linspace(300,3000,n)

K = np.empty((n,5))
a = np.empty((n,5))

for i in range(n):
    K[i,:], a[i,:] = w.get_k_a(T[i], P, XCO2, XH2O)
    #print(T[i], np.min(a[i,:]))
    
colors = cm.Blues(np.linspace(0.3,1,5))
plt.rc('font', size=14)
for i in range(len(a[0,:])):
    plt.plot(T,a[:,i], '-', color=colors[i], label=fr"a$_{i}$", lw=1)
plt.plot([2400,2400],[0,0.7], '--', color='gray', lw=1)
#plt.plot([2800,2800],[0,0.7], '--', color='gray', lw=1)
plt.plot([300,3000],[0,0], '--', color='gray', lw=1.0)
plt.ylim([-0.05,0.7])
plt.xlim([300,2800])
plt.xticks([300, 800, 1300, 1800, 2300, 2800])
plt.xlabel('T (K)')
plt.ylabel('a')
plt.title(rf'M$_r$={XH2O/XCO2}');
plt.legend(frameon=False, loc='upper left');
# Out:
# 4.000000000000001

# %%
T = 1000
XCO2 = 1.0
XH2O = np.linspace(0.0, 5, 1000)

for i in range(n):
    K[i,:], a[i,:] = w.get_k_a(T, P, XCO2, XH2O[i])
    
plt.rc('font', size=14)
plt.plot(XH2O,a[:,0])
plt.plot(XH2O,a[:,1])
plt.plot(XH2O,a[:,2])
plt.plot(XH2O,a[:,3])
plt.plot(XH2O,a[:,4])
plt.plot([4,4],[0,0.5])
plt.ylim([0,0.5]);
plt.xlabel(r'X$_{H2O}$')
plt.ylabel('a');

# %%
T = 1000
XH2O = np.linspace(0.0, 0.8, 1000)
XCO2 = 1.0-XH2O
Mr = XH2O/XCO2

for i in range(n):
    K[i,:], a[i,:] = w.get_k_a(T, P, XCO2[i], XH2O[i])
    
plt.rc('font', size=14)
plt.plot(XH2O,a[:,0])
plt.plot(XH2O,a[:,1])
plt.plot(XH2O,a[:,2])
plt.plot(XH2O,a[:,3])
plt.plot(XH2O,a[:,4])
#plt.ylim([0,0.5]);
plt.xlabel(r'x$_{H2O}$')
plt.ylabel('a');

plt.figure()
plt.plot(Mr,a[:,0])
plt.plot(Mr,a[:,1])
plt.plot(Mr,a[:,2])
plt.plot(Mr,a[:,3])
plt.plot(Mr,a[:,4])
plt.plot([0.01,0.01],[0,0.4])
plt.plot([4,4],[0,0.4])
plt.xlabel(r'M$_{r}$')
plt.ylabel('a');

# %%
T = 1000
XH2O = np.linspace(0.0, 0.8, 1000)
XCO2 = 1.0-XH2O
Mr = XH2O/XCO2

for i in range(n):
    K[i,:], a[i,:] = w.get_k_a(T, P, XCO2[i], XH2O[i])
    
plt.rc('font', size=14)
plt.plot(XH2O,K[:,1])
plt.xlabel(r'x$_{H2O}$')
plt.ylabel('K');

plt.figure()
plt.plot(Mr,K[:,1])
plt.xlabel(r'M$_{r}$')
plt.ylabel('K');

# %%
K,a = w.get_k_a(2000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.02000.0, P, XCO2, XH2O)
